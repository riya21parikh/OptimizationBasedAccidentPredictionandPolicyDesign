# %% [markdown]
# # XGBoost Sparse

# %%
tol = 1e-6
nonzero = coef_table[abs.(coef_table.coef) .> tol, :]

selected_features = Symbol.(nonzero.feature)

println("Using ", length(selected_features), " non-zero (sparse) features for XGBoost.")
# Out:
# Using 32 non-zero (sparse) features for XGBoost.

# %%
# Subset X_train and X_test to selected features only
X_train_xgb = select(X_train, selected_features)
X_test_xgb  = select(X_test,  selected_features)

# Labels: use original binary/int targets from train_df / test_df
y_train_xgb = collect(y_train_raw)   
y_test_xgb  = collect(y_test_raw)

println("Size of XGBoost training set: ", size(X_train_xgb), ", labels length: ", length(y_train_xgb))
println("Size of XGBoost test set:     ", size(X_test_xgb),  ", labels length: ", length(y_test_xgb))
# Out:
# Size of XGBoost training set: (137343, 32), labels length: 137343
# Size of XGBoost test set:     (5168, 32), labels length: 5168

# %%
# XGBoost model w grid search
seed = 42

max_depths        = [3, 5, 7, 9]
min_child_weights = [5, 10, 20, 30]
n_estimators_list = [20, 25, 50, 100]

grid_search_xgb = IAI.GridSearch(
    IAI.XGBoostClassifier(
        random_seed = seed,
    ),
    max_depth        = max_depths,
    min_child_weight = min_child_weights,
    n_estimators     = n_estimators_list,
)

IAI.fit_cv!(
    grid_search_xgb,
    X_train_xgb,
    y_train_xgb;
    validation_criterion = :auc,
    positive_label       = 1,             # HighSeverity = 1
    sample_weight        = :autobalance,  # handle class imbalance
    n_folds              = 5,
    verbose              = true,
)

# Best model + hyperparameters
best_model_xgb = IAI.get_learner(grid_search_xgb)

println("\nBest XGBoost hyperparameters:")
println("  Max depth:        ", best_model_xgb.max_depth)
println("  Min child weight: ", best_model_xgb.min_child_weight)
println("  n_estimators:     ", best_model_xgb.n_estimators)
# Out:
# fold 1; train: 0.5439; valid: 0.8811; min_child_weight=>5 n_estimators=>20 max_depth=>3
# fold 1; train: 0.5415; valid: 0.8808; min_child_weight=>10 n_estimators=>20 max_depth=>3
# fold 1; train: 0.539; valid: 0.8807; min_child_weight=>20 n_estimators=>20 max_depth=>3
# fold 1; train: 0.5364; valid: 0.879; min_child_weight=>30 n_estimators=>20 max_depth=>3
# fold 1; train: 0.5439; valid: 0.8811; min_child_weight=>5 n_estimators=>25 max_depth=>3
# fold 1; train: 0.5415; valid: 0.8808; min_child_weight=>10 n_estimators=>25 max_depth=>3
# fold 1; train: 0.539; valid: 0.8807; min_child_weight=>20 n_estimators=>25 max_depth=>3
# fold 1; train: 0.5364; valid: 0.879; min_child_weight=>30 n_estimators=>25 max_depth=>3
# fold 1; train: 0.5439; valid: 0.8811; min_child_weight=>5 n_estimators=>50 max_depth=>3
# fold 1; train: 0.5415; valid: 0.8808; min_child_weight=>10 n_estimators=>50 max_depth=>3
# fold 1; train: 0.539; valid: 0.8807; min_child_weight=>20 n_estimators=>50 max_depth=>3
# fold 1; train: 0.5364; valid: 0.879; min_child_weight=>30 n_estimators=>50 max_depth=>3
# fold 1; train: 0.5439; valid: 0.8811; min_child_weight=>5 n_estimators=>100 max_depth=>3
# fold 1; train: 0.5415; valid: 0.8808; min_child_weight=>10 n_estimators=>100 max_depth=>3
# fold 1; train: 0.539; valid: 0.8807; min_child_weight=>20 n_estimators=>100 max_depth=>3
# fold 1; train: 0.5364; valid: 0.879; min_child_weight=>30 n_estimators=>100 max_depth=>3
# fold 1; train: 0.739; valid: 0.8909; min_child_weight=>5 n_estimators=>20 max_depth=>5
# fold 1; train: 0.7311; valid: 0.8887; min_child_weight=>10 n_estimators=>20 max_depth=>5
# fold 1; train: 0.7316; valid: 0.8874; min_child_weight=>20 n_estimators=>20 max_depth=>5
# fold 1; train: 0.7257; valid: 0.8951; min_child_weight=>30 n_estimators=>20 max_depth=>5
# fold 1; train: 0.739; valid: 0.8909; min_child_weight=>5 n_estimators=>25 max_depth=>5
# fold 1; train: 0.7311; valid: 0.8887; min_child_weight=>10 n_estimators=>25 max_depth=>5
# fold 1; train: 0.7316; valid: 0.8874; min_child_weight=>20 n_estimators=>25 max_depth=>5
# fold 1; train: 0.7257; valid: 0.8951; min_child_weight=>30 n_estimators=>25 max_depth=>5
# fold 1; train: 0.739; valid: 0.8909; min_child_weight=>5 n_estimators=>50 max_depth=>5
# fold 1; train: 0.7311; valid: 0.8887; min_child_weight=>10 n_estimators=>50 max_depth=>5
# fold 1; train: 0.7316; valid: 0.8874; min_child_weight=>20 n_estimators=>50 max_depth=>5
# fold 1; train: 0.7257; valid: 0.8951; min_child_weight=>30 n_estimators=>50 max_depth=>5
# fold 1; train: 0.739; valid: 0.8909; min_child_weight=>5 n_estimators=>100 max_depth=>5
# fold 1; train: 0.7311; valid: 0.8887; min_child_weight=>10 n_estimators=>100 max_depth=>5
# fold 1; train: 0.7316; valid: 0.8874; min_child_weight=>20 n_estimators=>100 max_depth=>5
# fold 1; train: 0.7257; valid: 0.8951; min_child_weight=>30 n_estimators=>100 max_depth=>5
# fold 1; train: 0.8902; valid: 0.888; min_child_weight=>5 n_estimators=>20 max_depth=>7
# fold 1; train: 0.8827; valid: 0.8847; min_child_weight=>10 n_estimators=>20 max_depth=>7
# fold 1; train: 0.8755; valid: 0.893; min_child_weight=>20 n_estimators=>20 max_depth=>7
# fold 1; train: 0.8644; valid: 0.8893; min_child_weight=>30 n_estimators=>20 max_depth=>7
# fold 1; train: 0.8902; valid: 0.888; min_child_weight=>5 n_estimators=>25 max_depth=>7
# fold 1; train: 0.8827; valid: 0.8847; min_child_weight=>10 n_estimators=>25 max_depth=>7
# fold 1; train: 0.8755; valid: 0.893; min_child_weight=>20 n_estimators=>25 max_depth=>7
# fold 1; train: 0.8644; valid: 0.8893; min_child_weight=>30 n_estimators=>25 max_depth=>7
# fold 1; train: 0.8902; valid: 0.888; min_child_weight=>5 n_estimators=>50 max_depth=>7
# fold 1; train: 0.8827; valid: 0.8847; min_child_weight=>10 n_estimators=>50 max_depth=>7
# fold 1; train: 0.8755; valid: 0.893; min_child_weight=>20 n_estimators=>50 max_depth=>7
# fold 1; train: 0.8644; valid: 0.8893; min_child_weight=>30 n_estimators=>50 max_depth=>7
# fold 1; train: 0.8902; valid: 0.888; min_child_weight=>5 n_estimators=>100 max_depth=>7
# fold 1; train: 0.8827; valid: 0.8847; min_child_weight=>10 n_estimators=>100 max_depth=>7
# fold 1; train: 0.8755; valid: 0.893; min_child_weight=>20 n_estimators=>100 max_depth=>7
# fold 1; train: 0.8644; valid: 0.8893; min_child_weight=>30 n_estimators=>100 max_depth=>7
# fold 1; train: 0.9602; valid: 0.8983; min_child_weight=>5 n_estimators=>20 max_depth=>9
# fold 1; train: 0.9564; valid: 0.8907; min_child_weight=>10 n_estimators=>20 max_depth=>9
# fold 1; train: 0.9446; valid: 0.8907; min_child_weight=>20 n_estimators=>20 max_depth=>9
# fold 1; train: 0.9377; valid: 0.9; min_child_weight=>30 n_estimators=>20 max_depth=>9
# fold 1; train: 0.9602; valid: 0.8983; min_child_weight=>5 n_estimators=>25 max_depth=>9
# fold 1; train: 0.9564; valid: 0.8907; min_child_weight=>10 n_estimators=>25 max_depth=>9
# fold 1; train: 0.9446; valid: 0.8907; min_child_weight=>20 n_estimators=>25 max_depth=>9
# fold 1; train: 0.9377; valid: 0.9; min_child_weight=>30 n_estimators=>25 max_depth=>9
# fold 1; train: 0.9602; valid: 0.8983; min_child_weight=>5 n_estimators=>50 max_depth=>9
# fold 1; train: 0.9564; valid: 0.8907; min_child_weight=>10 n_estimators=>50 max_depth=>9
# fold 1; train: 0.9446; valid: 0.8907; min_child_weight=>20 n_estimators=>50 max_depth=>9
# fold 1; train: 0.9377; valid: 0.9; min_child_weight=>30 n_estimators=>50 max_depth=>9
# fold 1; train: 0.9602; valid: 0.8983; min_child_weight=>5 n_estimators=>100 max_depth=>9
# fold 1; train: 0.9564; valid: 0.8907; min_child_weight=>10 n_estimators=>100 max_depth=>9
# fold 1; train: 0.9446; valid: 0.8907; min_child_weight=>20 n_estimators=>100 max_depth=>9
# fold 1; train: 0.9377; valid: 0.9; min_child_weight=>30 n_estimators=>100 max_depth=>9
# fold 2; train: 0.5308; valid: 0.8939; min_child_weight=>5 n_estimators=>20 max_depth=>3
# fold 2; train: 0.5285; valid: 0.8911; min_child_weight=>10 n_estimators=>20 max_depth=>3
# fold 2; train: 0.5297; valid: 0.8939; min_child_weight=>20 n_estimators=>20 max_depth=>3
# fold 2; train: 0.5274; valid: 0.8947; min_child_weight=>30 n_estimators=>20 max_depth=>3
# fold 2; train: 0.5308; valid: 0.8939; min_child_weight=>5 n_estimators=>25 max_depth=>3
# fold 2; train: 0.5285; valid: 0.8911; min_child_weight=>10 n_estimators=>25 max_depth=>3
# fold 2; train: 0.5297; valid: 0.8939; min_child_weight=>20 n_estimators=>25 max_depth=>3
# fold 2; train: 0.5274; valid: 0.8947; min_child_weight=>30 n_estimators=>25 max_depth=>3
# fold 2; train: 0.5308; valid: 0.8939; min_child_weight=>5 n_estimators=>50 max_depth=>3
# fold 2; train: 0.5285; valid: 0.8911; min_child_weight=>10 n_estimators=>50 max_depth=>3
# fold 2; train: 0.5297; valid: 0.8939; min_child_weight=>20 n_estimators=>50 max_depth=>3
# fold 2; train: 0.5274; valid: 0.8947; min_child_weight=>30 n_estimators=>50 max_depth=>3
# fold 2; train: 0.5308; valid: 0.8939; min_child_weight=>5 n_estimators=>100 max_depth=>3
# fold 2; train: 0.5285; valid: 0.8911; min_child_weight=>10 n_estimators=>100 max_depth=>3
# fold 2; train: 0.5297; valid: 0.8939; min_child_weight=>20 n_estimators=>100 max_depth=>3
# fold 2; train: 0.5274; valid: 0.8947; min_child_weight=>30 n_estimators=>100 max_depth=>3
# fold 2; train: 0.7265; valid: 0.898; min_child_weight=>5 n_estimators=>20 max_depth=>5
# fold 2; train: 0.7319; valid: 0.8998; min_child_weight=>10 n_estimators=>20 max_depth=>5
# fold 2; train: 0.7308; valid: 0.9042; min_child_weight=>20 n_estimators=>20 max_depth=>5
# fold 2; train: 0.7292; valid: 0.9016; min_child_weight=>30 n_estimators=>20 max_depth=>5
# fold 2; train: 0.7265; valid: 0.898; min_child_weight=>5 n_estimators=>25 max_depth=>5
# fold 2; train: 0.7319; valid: 0.8998; min_child_weight=>10 n_estimators=>25 max_depth=>5
# fold 2; train: 0.7308; valid: 0.9042; min_child_weight=>20 n_estimators=>25 max_depth=>5
# fold 2; train: 0.7292; valid: 0.9016; min_child_weight=>30 n_estimators=>25 max_depth=>5
# fold 2; train: 0.7265; valid: 0.898; min_child_weight=>5 n_estimators=>50 max_depth=>5
# fold 2; train: 0.7319; valid: 0.8998; min_child_weight=>10 n_estimators=>50 max_depth=>5
# fold 2; train: 0.7308; valid: 0.9042; min_child_weight=>20 n_estimators=>50 max_depth=>5
# fold 2; train: 0.7292; valid: 0.9016; min_child_weight=>30 n_estimators=>50 max_depth=>5
# fold 2; train: 0.7265; valid: 0.898; min_child_weight=>5 n_estimators=>100 max_depth=>5
# fold 2; train: 0.7319; valid: 0.8998; min_child_weight=>10 n_estimators=>100 max_depth=>5
# fold 2; train: 0.7308; valid: 0.9042; min_child_weight=>20 n_estimators=>100 max_depth=>5
# fold 2; train: 0.7292; valid: 0.9016; min_child_weight=>30 n_estimators=>100 max_depth=>5
# fold 2; train: 0.8896; valid: 0.9007; min_child_weight=>5 n_estimators=>20 max_depth=>7
# fold 2; train: 0.889; valid: 0.9067; min_child_weight=>10 n_estimators=>20 max_depth=>7
# fold 2; train: 0.8719; valid: 0.9041; min_child_weight=>20 n_estimators=>20 max_depth=>7
# fold 2; train: 0.8643; valid: 0.9108; min_child_weight=>30 n_estimators=>20 max_depth=>7
# fold 2; train: 0.8896; valid: 0.9007; min_child_weight=>5 n_estimators=>25 max_depth=>7
# fold 2; train: 0.889; valid: 0.9067; min_child_weight=>10 n_estimators=>25 max_depth=>7
# fold 2; train: 0.8719; valid: 0.9041; min_child_weight=>20 n_estimators=>25 max_depth=>7
# fold 2; train: 0.8643; valid: 0.9108; min_child_weight=>30 n_estimators=>25 max_depth=>7
# fold 2; train: 0.8896; valid: 0.9007; min_child_weight=>5 n_estimators=>50 max_depth=>7
# fold 2; train: 0.889; valid: 0.9067; min_child_weight=>10 n_estimators=>50 max_depth=>7
# fold 2; train: 0.8719; valid: 0.9041; min_child_weight=>20 n_estimators=>50 max_depth=>7
# fold 2; train: 0.8643; valid: 0.9108; min_child_weight=>30 n_estimators=>50 max_depth=>7
# fold 2; train: 0.8896; valid: 0.9007; min_child_weight=>5 n_estimators=>100 max_depth=>7
# fold 2; train: 0.889; valid: 0.9067; min_child_weight=>10 n_estimators=>100 max_depth=>7
# fold 2; train: 0.8719; valid: 0.9041; min_child_weight=>20 n_estimators=>100 max_depth=>7
# fold 2; train: 0.8643; valid: 0.9108; min_child_weight=>30 n_estimators=>100 max_depth=>7
# fold 2; train: 0.9662; valid: 0.8958; min_child_weight=>5 n_estimators=>20 max_depth=>9
# fold 2; train: 0.9523; valid: 0.9042; min_child_weight=>10 n_estimators=>20 max_depth=>9
# fold 2; train: 0.9484; valid: 0.9116; min_child_weight=>20 n_estimators=>20 max_depth=>9
# fold 2; train: 0.9419; valid: 0.9129; min_child_weight=>30 n_estimators=>20 max_depth=>9
# fold 2; train: 0.9662; valid: 0.8958; min_child_weight=>5 n_estimators=>25 max_depth=>9
# fold 2; train: 0.9523; valid: 0.9042; min_child_weight=>10 n_estimators=>25 max_depth=>9
# fold 2; train: 0.9484; valid: 0.9116; min_child_weight=>20 n_estimators=>25 max_depth=>9
# fold 2; train: 0.9419; valid: 0.9129; min_child_weight=>30 n_estimators=>25 max_depth=>9
# fold 2; train: 0.9662; valid: 0.8958; min_child_weight=>5 n_estimators=>50 max_depth=>9
# fold 2; train: 0.9523; valid: 0.9042; min_child_weight=>10 n_estimators=>50 max_depth=>9
# fold 2; train: 0.9484; valid: 0.9116; min_child_weight=>20 n_estimators=>50 max_depth=>9
# fold 2; train: 0.9419; valid: 0.9129; min_child_weight=>30 n_estimators=>50 max_depth=>9
# fold 2; train: 0.9662; valid: 0.8958; min_child_weight=>5 n_estimators=>100 max_depth=>9
# fold 2; train: 0.9523; valid: 0.9042; min_child_weight=>10 n_estimators=>100 max_depth=>9
# fold 2; train: 0.9484; valid: 0.9116; min_child_weight=>20 n_estimators=>100 max_depth=>9
# fold 2; train: 0.9419; valid: 0.9129; min_child_weight=>30 n_estimators=>100 max_depth=>9
# fold 3; train: 0.54; valid: 0.8895; min_child_weight=>5 n_estimators=>20 max_depth=>3
# fold 3; train: 0.5392; valid: 0.8915; min_child_weight=>10 n_estimators=>20 max_depth=>3
# fold 3; train: 0.5359; valid: 0.8902; min_child_weight=>20 n_estimators=>20 max_depth=>3
# fold 3; train: 0.5366; valid: 0.89; min_child_weight=>30 n_estimators=>20 max_depth=>3
# fold 3; train: 0.54; valid: 0.8895; min_child_weight=>5 n_estimators=>25 max_depth=>3
# fold 3; train: 0.5392; valid: 0.8915; min_child_weight=>10 n_estimators=>25 max_depth=>3
# fold 3; train: 0.5359; valid: 0.8902; min_child_weight=>20 n_estimators=>25 max_depth=>3
# fold 3; train: 0.5366; valid: 0.89; min_child_weight=>30 n_estimators=>25 max_depth=>3
# fold 3; train: 0.54; valid: 0.8895; min_child_weight=>5 n_estimators=>50 max_depth=>3
# fold 3; train: 0.5392; valid: 0.8915; min_child_weight=>10 n_estimators=>50 max_depth=>3
# fold 3; train: 0.5359; valid: 0.8902; min_child_weight=>20 n_estimators=>50 max_depth=>3
# fold 3; train: 0.5366; valid: 0.89; min_child_weight=>30 n_estimators=>50 max_depth=>3
# fold 3; train: 0.54; valid: 0.8895; min_child_weight=>5 n_estimators=>100 max_depth=>3
# fold 3; train: 0.5392; valid: 0.8915; min_child_weight=>10 n_estimators=>100 max_depth=>3
# fold 3; train: 0.5359; valid: 0.8902; min_child_weight=>20 n_estimators=>100 max_depth=>3
# fold 3; train: 0.5366; valid: 0.89; min_child_weight=>30 n_estimators=>100 max_depth=>3
# fold 3; train: 0.7404; valid: 0.8962; min_child_weight=>5 n_estimators=>20 max_depth=>5
# fold 3; train: 0.7544; valid: 0.8943; min_child_weight=>10 n_estimators=>20 max_depth=>5
# fold 3; train: 0.7368; valid: 0.8916; min_child_weight=>20 n_estimators=>20 max_depth=>5
# fold 3; train: 0.7428; valid: 0.8957; min_child_weight=>30 n_estimators=>20 max_depth=>5
# fold 3; train: 0.7404; valid: 0.8962; min_child_weight=>5 n_estimators=>25 max_depth=>5
# fold 3; train: 0.7544; valid: 0.8943; min_child_weight=>10 n_estimators=>25 max_depth=>5
# fold 3; train: 0.7368; valid: 0.8916; min_child_weight=>20 n_estimators=>25 max_depth=>5
# fold 3; train: 0.7428; valid: 0.8957; min_child_weight=>30 n_estimators=>25 max_depth=>5
# fold 3; train: 0.7404; valid: 0.8962; min_child_weight=>5 n_estimators=>50 max_depth=>5
# fold 3; train: 0.7544; valid: 0.8943; min_child_weight=>10 n_estimators=>50 max_depth=>5
# fold 3; train: 0.7368; valid: 0.8916; min_child_weight=>20 n_estimators=>50 max_depth=>5
# fold 3; train: 0.7428; valid: 0.8957; min_child_weight=>30 n_estimators=>50 max_depth=>5
# fold 3; train: 0.7404; valid: 0.8962; min_child_weight=>5 n_estimators=>100 max_depth=>5
# fold 3; train: 0.7544; valid: 0.8943; min_child_weight=>10 n_estimators=>100 max_depth=>5
# fold 3; train: 0.7368; valid: 0.8916; min_child_weight=>20 n_estimators=>100 max_depth=>5
# fold 3; train: 0.7428; valid: 0.8957; min_child_weight=>30 n_estimators=>100 max_depth=>5
# fold 3; train: 0.899; valid: 0.8831; min_child_weight=>5 n_estimators=>20 max_depth=>7
# fold 3; train: 0.8913; valid: 0.8896; min_child_weight=>10 n_estimators=>20 max_depth=>7
# fold 3; train: 0.8776; valid: 0.8916; min_child_weight=>20 n_estimators=>20 max_depth=>7
# fold 3; train: 0.8811; valid: 0.8884; min_child_weight=>30 n_estimators=>20 max_depth=>7
# fold 3; train: 0.899; valid: 0.8831; min_child_weight=>5 n_estimators=>25 max_depth=>7
# fold 3; train: 0.8913; valid: 0.8896; min_child_weight=>10 n_estimators=>25 max_depth=>7
# fold 3; train: 0.8776; valid: 0.8916; min_child_weight=>20 n_estimators=>25 max_depth=>7
# fold 3; train: 0.8811; valid: 0.8884; min_child_weight=>30 n_estimators=>25 max_depth=>7
# fold 3; train: 0.899; valid: 0.8831; min_child_weight=>5 n_estimators=>50 max_depth=>7
# fold 3; train: 0.8913; valid: 0.8896; min_child_weight=>10 n_estimators=>50 max_depth=>7
# fold 3; train: 0.8776; valid: 0.8916; min_child_weight=>20 n_estimators=>50 max_depth=>7
# fold 3; train: 0.8811; valid: 0.8884; min_child_weight=>30 n_estimators=>50 max_depth=>7
# fold 3; train: 0.899; valid: 0.8831; min_child_weight=>5 n_estimators=>100 max_depth=>7
# fold 3; train: 0.8913; valid: 0.8896; min_child_weight=>10 n_estimators=>100 max_depth=>7
# fold 3; train: 0.8776; valid: 0.8916; min_child_weight=>20 n_estimators=>100 max_depth=>7
# fold 3; train: 0.8811; valid: 0.8884; min_child_weight=>30 n_estimators=>100 max_depth=>7
# fold 3; train: 0.9605; valid: 0.8856; min_child_weight=>5 n_estimators=>20 max_depth=>9
# fold 3; train: 0.9551; valid: 0.8948; min_child_weight=>10 n_estimators=>20 max_depth=>9
# fold 3; train: 0.9436; valid: 0.8946; min_child_weight=>20 n_estimators=>20 max_depth=>9
# fold 3; train: 0.9372; valid: 0.9034; min_child_weight=>30 n_estimators=>20 max_depth=>9
# fold 3; train: 0.9605; valid: 0.8856; min_child_weight=>5 n_estimators=>25 max_depth=>9
# fold 3; train: 0.9551; valid: 0.8948; min_child_weight=>10 n_estimators=>25 max_depth=>9
# fold 3; train: 0.9436; valid: 0.8946; min_child_weight=>20 n_estimators=>25 max_depth=>9
# fold 3; train: 0.9372; valid: 0.9034; min_child_weight=>30 n_estimators=>25 max_depth=>9
# fold 3; train: 0.9605; valid: 0.8856; min_child_weight=>5 n_estimators=>50 max_depth=>9
# fold 3; train: 0.9551; valid: 0.8948; min_child_weight=>10 n_estimators=>50 max_depth=>9
# fold 3; train: 0.9436; valid: 0.8946; min_child_weight=>20 n_estimators=>50 max_depth=>9
# fold 3; train: 0.9372; valid: 0.9034; min_child_weight=>30 n_estimators=>50 max_depth=>9
# fold 3; train: 0.9605; valid: 0.8856; min_child_weight=>5 n_estimators=>100 max_depth=>9
# fold 3; train: 0.9551; valid: 0.8948; min_child_weight=>10 n_estimators=>100 max_depth=>9
# fold 3; train: 0.9436; valid: 0.8946; min_child_weight=>20 n_estimators=>100 max_depth=>9
# fold 3; train: 0.9372; valid: 0.9034; min_child_weight=>30 n_estimators=>100 max_depth=>9
# fold 4; train: 0.5346; valid: 0.8835; min_child_weight=>5 n_estimators=>20 max_depth=>3
# fold 4; train: 0.5388; valid: 0.8883; min_child_weight=>10 n_estimators=>20 max_depth=>3
# fold 4; train: 0.5309; valid: 0.8849; min_child_weight=>20 n_estimators=>20 max_depth=>3
# fold 4; train: 0.5302; valid: 0.8854; min_child_weight=>30 n_estimators=>20 max_depth=>3
# fold 4; train: 0.5346; valid: 0.8835; min_child_weight=>5 n_estimators=>25 max_depth=>3
# fold 4; train: 0.5388; valid: 0.8883; min_child_weight=>10 n_estimators=>25 max_depth=>3
# fold 4; train: 0.5309; valid: 0.8849; min_child_weight=>20 n_estimators=>25 max_depth=>3
# fold 4; train: 0.5302; valid: 0.8854; min_child_weight=>30 n_estimators=>25 max_depth=>3
# fold 4; train: 0.5346; valid: 0.8835; min_child_weight=>5 n_estimators=>50 max_depth=>3
# fold 4; train: 0.5388; valid: 0.8883; min_child_weight=>10 n_estimators=>50 max_depth=>3
# fold 4; train: 0.5309; valid: 0.8849; min_child_weight=>20 n_estimators=>50 max_depth=>3
# fold 4; train: 0.5302; valid: 0.8854; min_child_weight=>30 n_estimators=>50 max_depth=>3
# fold 4; train: 0.5346; valid: 0.8835; min_child_weight=>5 n_estimators=>100 max_depth=>3
# fold 4; train: 0.5388; valid: 0.8883; min_child_weight=>10 n_estimators=>100 max_depth=>3
# fold 4; train: 0.5309; valid: 0.8849; min_child_weight=>20 n_estimators=>100 max_depth=>3
# fold 4; train: 0.5302; valid: 0.8854; min_child_weight=>30 n_estimators=>100 max_depth=>3
# fold 4; train: 0.7359; valid: 0.8928; min_child_weight=>5 n_estimators=>20 max_depth=>5
# fold 4; train: 0.7366; valid: 0.8917; min_child_weight=>10 n_estimators=>20 max_depth=>5
# fold 4; train: 0.7312; valid: 0.8975; min_child_weight=>20 n_estimators=>20 max_depth=>5
# fold 4; train: 0.7164; valid: 0.8984; min_child_weight=>30 n_estimators=>20 max_depth=>5
# fold 4; train: 0.7359; valid: 0.8928; min_child_weight=>5 n_estimators=>25 max_depth=>5
# fold 4; train: 0.7366; valid: 0.8917; min_child_weight=>10 n_estimators=>25 max_depth=>5
# fold 4; train: 0.7312; valid: 0.8975; min_child_weight=>20 n_estimators=>25 max_depth=>5
# fold 4; train: 0.7164; valid: 0.8984; min_child_weight=>30 n_estimators=>25 max_depth=>5
# fold 4; train: 0.7359; valid: 0.8928; min_child_weight=>5 n_estimators=>50 max_depth=>5
# fold 4; train: 0.7366; valid: 0.8917; min_child_weight=>10 n_estimators=>50 max_depth=>5
# fold 4; train: 0.7312; valid: 0.8975; min_child_weight=>20 n_estimators=>50 max_depth=>5
# fold 4; train: 0.7164; valid: 0.8984; min_child_weight=>30 n_estimators=>50 max_depth=>5
# fold 4; train: 0.7359; valid: 0.8928; min_child_weight=>5 n_estimators=>100 max_depth=>5
# fold 4; train: 0.7366; valid: 0.8917; min_child_weight=>10 n_estimators=>100 max_depth=>5
# fold 4; train: 0.7312; valid: 0.8975; min_child_weight=>20 n_estimators=>100 max_depth=>5
# fold 4; train: 0.7164; valid: 0.8984; min_child_weight=>30 n_estimators=>100 max_depth=>5
# fold 4; train: 0.8787; valid: 0.8951; min_child_weight=>5 n_estimators=>20 max_depth=>7
# fold 4; train: 0.8816; valid: 0.8938; min_child_weight=>10 n_estimators=>20 max_depth=>7
# fold 4; train: 0.8792; valid: 0.8981; min_child_weight=>20 n_estimators=>20 max_depth=>7
# fold 4; train: 0.8644; valid: 0.9007; min_child_weight=>30 n_estimators=>20 max_depth=>7
# fold 4; train: 0.8787; valid: 0.8951; min_child_weight=>5 n_estimators=>25 max_depth=>7
# fold 4; train: 0.8816; valid: 0.8938; min_child_weight=>10 n_estimators=>25 max_depth=>7
# fold 4; train: 0.8792; valid: 0.8981; min_child_weight=>20 n_estimators=>25 max_depth=>7
# fold 4; train: 0.8644; valid: 0.9007; min_child_weight=>30 n_estimators=>25 max_depth=>7
# fold 4; train: 0.8787; valid: 0.8951; min_child_weight=>5 n_estimators=>50 max_depth=>7
# fold 4; train: 0.8816; valid: 0.8938; min_child_weight=>10 n_estimators=>50 max_depth=>7
# fold 4; train: 0.8792; valid: 0.8981; min_child_weight=>20 n_estimators=>50 max_depth=>7
# fold 4; train: 0.8644; valid: 0.9007; min_child_weight=>30 n_estimators=>50 max_depth=>7
# fold 4; train: 0.8787; valid: 0.8951; min_child_weight=>5 n_estimators=>100 max_depth=>7
# fold 4; train: 0.8816; valid: 0.8938; min_child_weight=>10 n_estimators=>100 max_depth=>7
# fold 4; train: 0.8792; valid: 0.8981; min_child_weight=>20 n_estimators=>100 max_depth=>7
# fold 4; train: 0.8644; valid: 0.9007; min_child_weight=>30 n_estimators=>100 max_depth=>7
# fold 4; train: 0.9567; valid: 0.8896; min_child_weight=>5 n_estimators=>20 max_depth=>9
# fold 4; train: 0.9522; valid: 0.8987; min_child_weight=>10 n_estimators=>20 max_depth=>9
# fold 4; train: 0.9475; valid: 0.9033; min_child_weight=>20 n_estimators=>20 max_depth=>9
# fold 4; train: 0.933; valid: 0.8955; min_child_weight=>30 n_estimators=>20 max_depth=>9
# fold 4; train: 0.9567; valid: 0.8896; min_child_weight=>5 n_estimators=>25 max_depth=>9
# fold 4; train: 0.9522; valid: 0.8987; min_child_weight=>10 n_estimators=>25 max_depth=>9
# fold 4; train: 0.9475; valid: 0.9033; min_child_weight=>20 n_estimators=>25 max_depth=>9
# fold 4; train: 0.933; valid: 0.8955; min_child_weight=>30 n_estimators=>25 max_depth=>9
# fold 4; train: 0.9567; valid: 0.8896; min_child_weight=>5 n_estimators=>50 max_depth=>9
# fold 4; train: 0.9522; valid: 0.8987; min_child_weight=>10 n_estimators=>50 max_depth=>9
# fold 4; train: 0.9475; valid: 0.9033; min_child_weight=>20 n_estimators=>50 max_depth=>9
# fold 4; train: 0.933; valid: 0.8955; min_child_weight=>30 n_estimators=>50 max_depth=>9
# fold 4; train: 0.9567; valid: 0.8896; min_child_weight=>5 n_estimators=>100 max_depth=>9
# fold 4; train: 0.9522; valid: 0.8987; min_child_weight=>10 n_estimators=>100 max_depth=>9
# fold 4; train: 0.9475; valid: 0.9033; min_child_weight=>20 n_estimators=>100 max_depth=>9
# fold 4; train: 0.933; valid: 0.8955; min_child_weight=>30 n_estimators=>100 max_depth=>9
# fold 5; train: 0.5378; valid: 0.885; min_child_weight=>5 n_estimators=>20 max_depth=>3
# fold 5; train: 0.5351; valid: 0.8881; min_child_weight=>10 n_estimators=>20 max_depth=>3
# fold 5; train: 0.539; valid: 0.8922; min_child_weight=>20 n_estimators=>20 max_depth=>3
# fold 5; train: 0.529; valid: 0.8874; min_child_weight=>30 n_estimators=>20 max_depth=>3
# fold 5; train: 0.5378; valid: 0.885; min_child_weight=>5 n_estimators=>25 max_depth=>3
# fold 5; train: 0.5351; valid: 0.8881; min_child_weight=>10 n_estimators=>25 max_depth=>3
# fold 5; train: 0.539; valid: 0.8922; min_child_weight=>20 n_estimators=>25 max_depth=>3
# fold 5; train: 0.529; valid: 0.8874; min_child_weight=>30 n_estimators=>25 max_depth=>3
# fold 5; train: 0.5378; valid: 0.885; min_child_weight=>5 n_estimators=>50 max_depth=>3
# fold 5; train: 0.5351; valid: 0.8881; min_child_weight=>10 n_estimators=>50 max_depth=>3
# fold 5; train: 0.539; valid: 0.8922; min_child_weight=>20 n_estimators=>50 max_depth=>3
# fold 5; train: 0.529; valid: 0.8874; min_child_weight=>30 n_estimators=>50 max_depth=>3
# fold 5; train: 0.5378; valid: 0.885; min_child_weight=>5 n_estimators=>100 max_depth=>3
# fold 5; train: 0.5351; valid: 0.8881; min_child_weight=>10 n_estimators=>100 max_depth=>3
# fold 5; train: 0.539; valid: 0.8922; min_child_weight=>20 n_estimators=>100 max_depth=>3
# fold 5; train: 0.529; valid: 0.8874; min_child_weight=>30 n_estimators=>100 max_depth=>3
# fold 5; train: 0.747; valid: 0.8982; min_child_weight=>5 n_estimators=>20 max_depth=>5
# fold 5; train: 0.7379; valid: 0.8995; min_child_weight=>10 n_estimators=>20 max_depth=>5
# fold 5; train: 0.7273; valid: 0.8976; min_child_weight=>20 n_estimators=>20 max_depth=>5
# fold 5; train: 0.7292; valid: 0.9057; min_child_weight=>30 n_estimators=>20 max_depth=>5
# fold 5; train: 0.747; valid: 0.8982; min_child_weight=>5 n_estimators=>25 max_depth=>5
# fold 5; train: 0.7379; valid: 0.8995; min_child_weight=>10 n_estimators=>25 max_depth=>5
# fold 5; train: 0.7273; valid: 0.8976; min_child_weight=>20 n_estimators=>25 max_depth=>5
# fold 5; train: 0.7292; valid: 0.9057; min_child_weight=>30 n_estimators=>25 max_depth=>5
# fold 5; train: 0.747; valid: 0.8982; min_child_weight=>5 n_estimators=>50 max_depth=>5
# fold 5; train: 0.7379; valid: 0.8995; min_child_weight=>10 n_estimators=>50 max_depth=>5
# fold 5; train: 0.7273; valid: 0.8976; min_child_weight=>20 n_estimators=>50 max_depth=>5
# fold 5; train: 0.7292; valid: 0.9057; min_child_weight=>30 n_estimators=>50 max_depth=>5
# fold 5; train: 0.747; valid: 0.8982; min_child_weight=>5 n_estimators=>100 max_depth=>5
# fold 5; train: 0.7379; valid: 0.8995; min_child_weight=>10 n_estimators=>100 max_depth=>5
# fold 5; train: 0.7273; valid: 0.8976; min_child_weight=>20 n_estimators=>100 max_depth=>5
# fold 5; train: 0.7292; valid: 0.9057; min_child_weight=>30 n_estimators=>100 max_depth=>5
# fold 5; train: 0.8856; valid: 0.9031; min_child_weight=>5 n_estimators=>20 max_depth=>7
# fold 5; train: 0.8725; valid: 0.9092; min_child_weight=>10 n_estimators=>20 max_depth=>7
# fold 5; train: 0.8776; valid: 0.9109; min_child_weight=>20 n_estimators=>20 max_depth=>7
# fold 5; train: 0.8727; valid: 0.9118; min_child_weight=>30 n_estimators=>20 max_depth=>7
# fold 5; train: 0.8856; valid: 0.9031; min_child_weight=>5 n_estimators=>25 max_depth=>7
# fold 5; train: 0.8725; valid: 0.9092; min_child_weight=>10 n_estimators=>25 max_depth=>7
# fold 5; train: 0.8776; valid: 0.9109; min_child_weight=>20 n_estimators=>25 max_depth=>7
# fold 5; train: 0.8727; valid: 0.9118; min_child_weight=>30 n_estimators=>25 max_depth=>7
# fold 5; train: 0.8856; valid: 0.9031; min_child_weight=>5 n_estimators=>50 max_depth=>7
# fold 5; train: 0.8725; valid: 0.9092; min_child_weight=>10 n_estimators=>50 max_depth=>7
# fold 5; train: 0.8776; valid: 0.9109; min_child_weight=>20 n_estimators=>50 max_depth=>7
# fold 5; train: 0.8727; valid: 0.9118; min_child_weight=>30 n_estimators=>50 max_depth=>7
# fold 5; train: 0.8856; valid: 0.9031; min_child_weight=>5 n_estimators=>100 max_depth=>7
# fold 5; train: 0.8725; valid: 0.9092; min_child_weight=>10 n_estimators=>100 max_depth=>7
# fold 5; train: 0.8776; valid: 0.9109; min_child_weight=>20 n_estimators=>100 max_depth=>7
# fold 5; train: 0.8727; valid: 0.9118; min_child_weight=>30 n_estimators=>100 max_depth=>7
# fold 5; train: 0.9603; valid: 0.9131; min_child_weight=>5 n_estimators=>20 max_depth=>9
# fold 5; train: 0.9531; valid: 0.9037; min_child_weight=>10 n_estimators=>20 max_depth=>9
# fold 5; train: 0.9421; valid: 0.9153; min_child_weight=>20 n_estimators=>20 max_depth=>9
# fold 5; train: 0.933; valid: 0.9186; min_child_weight=>30 n_estimators=>20 max_depth=>9
# fold 5; train: 0.9603; valid: 0.9131; min_child_weight=>5 n_estimators=>25 max_depth=>9
# fold 5; train: 0.9531; valid: 0.9037; min_child_weight=>10 n_estimators=>25 max_depth=>9
# fold 5; train: 0.9421; valid: 0.9153; min_child_weight=>20 n_estimators=>25 max_depth=>9
# fold 5; train: 0.933; valid: 0.9186; min_child_weight=>30 n_estimators=>25 max_depth=>9
# fold 5; train: 0.9603; valid: 0.9131; min_child_weight=>5 n_estimators=>50 max_depth=>9
# fold 5; train: 0.9531; valid: 0.9037; min_child_weight=>10 n_estimators=>50 max_depth=>9
# fold 5; train: 0.9421; valid: 0.9153; min_child_weight=>20 n_estimators=>50 max_depth=>9
# fold 5; train: 0.933; valid: 0.9186; min_child_weight=>30 n_estimators=>50 max_depth=>9
# fold 5; train: 0.9603; valid: 0.9131; min_child_weight=>5 n_estimators=>100 max_depth=>9
# fold 5; train: 0.9531; valid: 0.9037; min_child_weight=>10 n_estimators=>100 max_depth=>9
# fold 5; train: 0.9421; valid: 0.9153; min_child_weight=>20 n_estimators=>100 max_depth=>9
# fold 5; train: 0.933; valid: 0.9186; min_child_weight=>30 n_estimators=>100 max_depth=>9
#
# Best XGBoost hyperparameters:
#   Max depth:        9
#   Min child weight: 30
#   n_estimators:     20

# %%
# Metrics = AUC, Accuracy, Recall
# Training metrics 
train_auc_xgb = IAI.score(
    best_model_xgb, X_train_xgb, y_train_xgb;
    criterion      = :auc,
    positive_label = 1,
)

train_acc_xgb = IAI.score(
    best_model_xgb, X_train_xgb, y_train_xgb;
    criterion      = :accuracy,
    positive_label = 1,
)

train_recall_xgb = IAI.score(
    best_model_xgb, X_train_xgb, y_train_xgb;
    criterion      = :sensitivity,   # recall
    positive_label = 1,
)

println("\nXGBoost Training AUC:      ", round(train_auc_xgb, digits=4))
println("XGBoost Training Accuracy: ", round(train_acc_xgb, digits=4))
println("XGBoost Training Recall:   ", round(train_recall_xgb, digits=4))

# Test metrics
test_auc_xgb = IAI.score(
    best_model_xgb, X_test_xgb, y_test_xgb;
    criterion      = :auc,
    positive_label = 1,
)

test_acc_xgb = IAI.score(
    best_model_xgb, X_test_xgb, y_test_xgb;
    criterion      = :accuracy,
    positive_label = 1,
)

test_recall_xgb = IAI.score(
    best_model_xgb, X_test_xgb, y_test_xgb;
    criterion      = :sensitivity,   # recall
    positive_label = 1,
)

println("\nXGBoost Test AUC:          ", round(test_auc_xgb, digits=4))
println("XGBoost Test Accuracy:     ", round(test_acc_xgb, digits=4))
println("XGBoost Test Recall:       ", round(test_recall_xgb, digits=4))

# Predictions & probabilities
y_pred_train_xgb = IAI.predict(best_model_xgb, X_train_xgb)
y_pred_test_xgb  = IAI.predict(best_model_xgb, X_test_xgb)

y_prob_train_xgb = IAI.predict_proba(best_model_xgb, X_train_xgb)
y_prob_test_xgb  = IAI.predict_proba(best_model_xgb, X_test_xgb)
# Out:
# XGBoost Training AUC:      0.9994
# XGBoost Training Accuracy: 0.9834
# XGBoost Training Recall:   1.0
#
# XGBoost Test AUC:          0.6819
# XGBoost Test Accuracy:     0.9646
# XGBoost Test Recall:       0.0
# 5168×2 DataFrame
#   Row │ 0          1
#       │ Float64    Float64
# ──────┼────────────────────────
#     1 │ 0.777604   0.222396
#     2 │ 0.982732   0.0172677
#     3 │ 0.377769   0.622231
#     4 │ 0.971726   0.0282745
#     5 │ 0.739691   0.260309
#     6 │ 0.472083   0.527917
#     7 │ 0.996734   0.00326593
#     8 │ 0.939842   0.0601579
#     9 │ 0.855948   0.144052
#    10 │ 0.998596   0.0014041
#    11 │ 0.946581   0.0534191
#   ⋮   │     ⋮           ⋮
#  5159 │ 0.99003    0.0099697
#  5160 │ 0.999204   0.000795693
#  5161 │ 0.999083   0.000916796
#  5162 │ 0.991223   0.00877653
#  5163 │ 0.993918   0.0060822
#  5164 │ 0.314843   0.685157
#  5165 │ 0.990732   0.00926801
#  5166 │ 0.930372   0.0696283
#  5167 │ 0.990977   0.0090232
#  5168 │ 0.99952    0.000479619
#               5147 rows omitted

# %%
# Take P(y=1) from train and test
prob_train = y_prob_train_xgb[:, 2]
prob_test  = y_prob_test_xgb[:, 2]

# Train on top, test 2023 on bottom
prob_all = vcat(prob_train, prob_test)

prob_df = DataFrame(
    prob_class1 = prob_all,
)

CSV.write("sparseyhat_xg.csv", prob_df)
# Out:
# "sparseyhat_xg.csv"
